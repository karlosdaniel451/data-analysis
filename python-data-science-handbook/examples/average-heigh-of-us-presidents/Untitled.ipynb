# %%
import numpy as np
import pandas as pd

data = pd.read_csv('./data/president_heights.csv')
data.head()
# Out:
#    order               name  height(cm)
# 0      1  George Washington         189
# 1      2         John Adams         170
# 2      3   Thomas Jefferson         189
# 3      4      James Madison         163
# 4      5       James Monroe         183

# %%
heights = np.array(data['height(cm)'])
print(heights)
# Out:
# [189 170 189 163 183 171 185 168 173 183 173 173 175 178 183 193 178 173
#  174 183 183 168 170 178 182 180 183 178 182 188 175 179 183 193 182 183
#  177 185 188 188 182 185]

# %%
print(f'Mean height:           {heights.mean():.2f}')
print(f'Standard deviation:    {heights.std():.2f}')
print(f'Minimum height:        {heights.min()}')
print(f'Maximum height:        {heights.max()}')
# Out:
# Mean height:           179.74
# Standard deviation:    6.93
# Minimum height:        163
# Maximum height:        193

# %%
print(f'25th percentile:    {np.percentile(heights, 25)}')
print(f'Median:             {np.median(heights)}')
print(f'75th percentile:    {np.percentile(heights, 75)}')
# Out:
# 25th percentile:    174.25
# Median:             182.0
# 75th percentile:    183.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()  # set plot style

plt.hist(heights)
plt.title('Height distribution of US Presidents')
plt.xlabel('Height (cm)')
plt.ylabel('Number')
# Out:
# Text(0, 0.5, 'Number')

# %%
# Another histogram but with more equal-width bins
plt.hist(heights, bins=20)
plt.title('Height distribution of US Presidents')
plt.xlabel('Height (cm)')
plt.ylabel('Number')
# Out:
# Text(0, 0.5, 'Number')

# %%
fig1, ax1 = plt.subplots()  # Reference: https://matplotlib.org/stable/gallery/pyplots/boxplot_demo_pyplot.html#sphx-glr-gallery-pyplots-boxplot-demo-pyplot-py
ax1.set_title('US Presidents heights boxplot')
ax1.boxplot(heights, showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f0c9205cf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f0c9206230>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f0c9205a50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f0c9206770>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f0c9206cb0>],
#  'means': [<matplotlib.lines.Line2D at 0x1f0c9206a10>]}
